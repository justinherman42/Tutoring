# %%
import pymysql
import json
from pandas.io.json import json_normalize

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

def get_jsonparsed_data(url):
    response = urlopen(url)
    data = json.loads(response.read().decode("utf-8"))
    df = json_normalize(data['financials'])
    return df

url = ("https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/AAPL?period=quarter")
df = get_jsonparsed_data(url)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
json_normalize(data["financials"])
# Out:
#    Cash and cash equivalents Cash and short-term investments Deferred revenue  \
# 0              50530000000.0                   94614000000.0     5434000000.0
# 1              37988000000.0                   80092000000.0     5532000000.0
# 2              44771000000.0                   86427000000.0     5546000000.0
# 3              25913000000.0                   66301000000.0     5966000000.0
# 4              31971000000.0                   70970000000.0    10281000000.0
# 5              45059000000.0                   87940000000.0    10862000000.0
# 6              27491000000.0                   77153000000.0    11175000000.0
# 7              20289000000.0                   74181000000.0    10384000000.0
# 8              18571000000.0                   76759000000.0    10592000000.0
# 9              15157000000.0                   67101000000.0    10789000000.0
# 10             16371000000.0                   60452000000.0    11052000000.0
# ...

# %%
db = pymysql.connect("localhost","root","Joia0341##","xmedia" )

# prepare a cursor object using cursor() method
cursor = db.cursor()

# execute SQL query using execute() method.
cursor.execute("SELECT VERSION()")

# Fetch a single row using fetchone() method.
data = cursor.fetchone()
print ("Database version : %s " % data)

# disconnect from server
#db.close()
# Out:
# Database version : 5.7.26-log

# %%
cursor.execute("DROP TABLE IF EXISTS EMPLOYEE")

# Create table as per requirement
sql = """'Cash and cash equivalents, Cash and short-term investments, Deferred revenue, Deposit Liabilities,\
Goodwill and Intangible Assets, Inventories, Investments, Long-term debt, Long-term investments, Net Debt,\
Other Assets, Other Liabilities, Other comprehensive income, Payables, Property, Plant & Equipment Net,\
Receivables, Retained earnings (deficit), Short-term debt, Short-term investments, Tax Liabilities,\
Tax assets, Total assets, Total current assets, Total current liabilities, Total debt, Total liabilities,\
Total non-current assets, Total non-current liabilities, Total shareholders equity, date\

'"""

cursor.execute(sql)

# %%
columns_insert = ', '.join(str(elem) for elem in df.columns)
columns_insert
values_insert= "%s, "*30

# %%
columns_insert
# Out:
# 'Cash and cash equivalents, Cash and short-term investments, Deferred revenue, Deposit Liabilities, Goodwill and Intangible Assets, Inventories, Investments, Long-term debt, Long-term investments, Net Debt, Other Assets, Other Liabilities, Other comprehensive income, Payables, Property, Plant & Equipment Net, Receivables, Retained earnings (deficit), Short-term debt, Short-term investments, Tax Liabilities, Tax assets, Total assets, Total current assets, Total current liabilities, Total debt, Total liabilities, Total non-current assets, Total non-current liabilities, Total shareholders equity, date'

# %%
user = 'root'
passw = 'Joia0341##'
host =  '172.17.0.2'
port = 3306
database = 'xmedia'

conn = pymysql.connect(host=host, port=port, user=user, passwd=passw)

conn.cursor().execute("CREATE DATABASE IF NOT EXISTS {0} ".format(database))
conn = pymysql.connect(host=host,
                       port=port,
                       user=user, 
                       passwd=passw,  
                       db=database,
                       charset='utf8')

data.to_sql(name=database, con=conn, if_exists = 'replace', index=False, flavor = 'mysql')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# E:\Anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# E:\Anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
import sqlalchemy as sa
import pandas as pd
from sqlalchemy import create_engine

# %%
cnx = create_engine('mysql+pymysql://[root]:[Joia0341##]@[172.17.0.2]:[3306]/[xmedia]', echo=False)
#df.to_sql("table_name", e, if_exists="replace", index=False)

# %%
data3 = pd.read_sql('SELECT * FROM testtable', cnx)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# E:\Anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# E:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# ...

# %%
cnx
# Out:
# Engine(mysql+pymysql://[host]:***@[172.17.0.2]:[3306]/[xmedia])

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine


user = 'root'
passw = 'Joia0341##'
host =  '172.17.0.2'
port = 3306
database = 'xmedia'


mydb = create_engine('mysql+pymysql://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)

# %%
mydb
# Out:
# Engine(mysql+pymysql://root:***@172.17.0.2:3306/xmedia)

# %%
data.to_sql(name=database, con=mydb, if_exists = 'append', index=False, flavor = 'mysql')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-8500abb6c73b> in <module>
# ----> 1 data.to_sql(name=database, con=mydb, if_exists = 'append', index=False, flavor = 'mysql')
#
# TypeError: to_sql() got an unexpected keyword argument 'flavor'

# %%
pd.io.sql._SQLALCHEMY_INSTALLED = True
